# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_result_cas_1 = pd.read_csv('1modif_apport_hy1_stock_hy1_result.csv', sep=';')
df_result_cas_2 = pd.read_csv('2modif_apport_hy1_stock_hy2_result.csv', sep=';')
df_low_high = pd.read_excel('Donnees.xlsx', sheet_name='Stock_hydro', usecols='L,N', skiprows=3, nrows=8736, names=['low', 'high'])


df_result_cas_1['pourcentage_hydro'] = df_result_cas_1['Hydro_stock '] / 1400000 * 100
df_result_cas_2['pourcentage_hydro'] = df_result_cas_2['Hydro_stock '] / 1400000 * 100
df = pd.DataFrame({'Date' : df_result_cas_1['Date '],
                   'low': df_low_high['low'],
                    'high': df_low_high['high'],
                    'cas1': df_result_cas_1['pourcentage_hydro'],
                    'cas2': df_result_cas_2['pourcentage_hydro']})

# %%
df.plot(x='Date',
        y=['low', 'high', 'cas1', 'cas2'],
        figsize=(10,6),
        title='Evolution du stock hydroélectrique apport 1 cas 1 et cas 2',
        ylim=(0, 100),
        rot = 70)
# Out:
# <AxesSubplot:title={'center':'Evolution du stock hydroélectrique apport 1 cas 1 et cas 2'}, xlabel='Date'>

# %%
df_result_cas_1 = pd.read_csv('3modif_apport_hy2_stock_hy1_result.csv', sep=';')
df_result_cas_2 = pd.read_csv('4modif_apport_hy2_stock_hy2_result.csv', sep=';')
df_low_high = pd.read_excel('Donnees.xlsx', sheet_name='Stock_hydro', usecols='L,N', skiprows=3, nrows=8736, names=['low', 'high'])


df_result_cas_1['pourcentage_hydro'] = df_result_cas_1['Hydro_stock '] / 1400000 * 100
df_result_cas_2['pourcentage_hydro'] = df_result_cas_2['Hydro_stock '] / 1400000 * 100
df = pd.DataFrame({'Date' : df_result_cas_1['Date '],
                   'low': df_low_high['low'],
                    'high': df_low_high['high'],
                    'cas1': df_result_cas_1['pourcentage_hydro'],
                    'cas2': df_result_cas_2['pourcentage_hydro']})

# %%
df.plot(x='Date',
        y=['low', 'high', 'cas1', 'cas2'],
        figsize=(10,6),
        title='Evolution du stock hydroélectrique apport 2 cas 1 et cas 2',
        ylim=(0, 100),
        rot = 70)
# Out:
# <AxesSubplot:title={'center':'Evolution du stock hydroélectrique apport 2 cas 1 et cas 2'}, xlabel='Date'>

# %%
df_result_cas_1 = pd.read_csv('5modif_apport_hy3_stock_hy1_result.csv', sep=';')
df_result_cas_2 = pd.read_csv('6modif_apport_hy3_stock_hy2_result.csv', sep=';')
df_low_high = pd.read_excel('Donnees.xlsx', sheet_name='Stock_hydro', usecols='L,N', skiprows=3, nrows=8736, names=['low', 'high'])


df_result_cas_1['pourcentage_hydro'] = df_result_cas_1['Hydro_stock '] / 1400000 * 100
df_result_cas_2['pourcentage_hydro'] = df_result_cas_2['Hydro_stock '] / 1400000 * 100
df = pd.DataFrame({'Date' : df_result_cas_1['Date '],
                   'low': df_low_high['low'],
                    'high': df_low_high['high'],
                    'cas1': df_result_cas_1['pourcentage_hydro'],
                    'cas2': df_result_cas_2['pourcentage_hydro']})

# %%
df.plot(x='Date',
        y=['low', 'high', 'cas1', 'cas2'],
        figsize=(10,6),
        title='Evolution du stock hydroélectrique apport 3 cas 1 et cas 2',
        ylim=(0, 100),
        rot = 70)
# Out:
# <AxesSubplot:title={'center':'Evolution du stock hydroélectrique apport 3 cas 1 et cas 2'}, xlabel='Date'>

# %%
df_result_cas_1 = pd.read_csv('7modif_apport_hy4_stock_hy1_result.csv', sep=';')
df_result_cas_2 = pd.read_csv('8modif_apport_hy4_stock_hy2_result.csv', sep=';')
df_low_high = pd.read_excel('Donnees.xlsx', sheet_name='Stock_hydro', usecols='L,N', skiprows=3, nrows=8736, names=['low', 'high'])


df_result_cas_1['pourcentage_hydro'] = df_result_cas_1['Hydro_stock '] / 1400000 * 100
df_result_cas_2['pourcentage_hydro'] = df_result_cas_2['Hydro_stock '] / 1400000 * 100
df = pd.DataFrame({'Date' : df_result_cas_1['Date '],
                   'low': df_low_high['low'],
                    'high': df_low_high['high'],
                    'cas1': df_result_cas_1['pourcentage_hydro'],
                    'cas2': df_result_cas_2['pourcentage_hydro']})

# %%
df.plot(x='Date',
        y=['low', 'high', 'cas1', 'cas2'],
        figsize=(10,6),
        title='Evolution du stock hydroélectrique apport 4 cas 1 et cas 2',
        ylim=(0, 100),
        rot = 70)
